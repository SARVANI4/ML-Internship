# %%
import os

# %%
os.chdir("C:/Users/saisaran/Desktop/DATA_SETS")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt    #for plotting of graphs
# %matplotlib inline
air=pd.read_csv("DelayedFlights (1).csv")

# %%
air
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008      1           3          4     2003        1955
# 1                 1  2008      1           3          4      754         735
# 2                 2  2008      1           3          4      628         620
# 3                 4  2008      1           3          4     1829        1755
# 4                 5  2008      1           3          4     1940        1915
# 5                 6  2008      1           3          4     1937        1830
# 6                10  2008      1           3          4      706         700
# 7                11  2008      1           3          4     1644        1510
# 8                15  2008      1           3          4     1029        1020
# 9                16  2008      1           3          4     1452        1425
# 10               17  2008      1           3          4      754         745
# 11               18  2008      1           3          4     1323        1255
# 12               19  2008      1           3          4     1416        1325
# 13               21  2008      1           3          4     1657        1625
# 14               22  2008      1           3          4     1900        1840
# 15               23  2008      1           3          4     1039        1030
# 16               25  2008      1           3          4     1520        1455
# 17               26  2008      1           3          4     1422        1255
# 18               27  2008      1           3          4     1954        1925
# 19               30  2008      1           3          4     2107        1945
# 20               33  2008      1           3          4     1312        1300
# 21               34  2008      1           3          4     1449        1430
# 22               35  2008      1           3          4     1634        1555
# 23               37  2008      1           3          4     1812        1650
# 24               38  2008      1           3          4     1127        1105
# 25               39  2008      1           3          4     1424        1355
# 26               40  2008      1           3          4     1326        1230
# 27               41  2008      1           3          4     1749        1725
# 28               42  2008      1           3          4      726         720
# 29               43  2008      1           3          4      646         640
# ...             ...   ...    ...         ...        ...      ...         ...
# 1048545     3504962  2008      6          29          7     1310        1300
# 1048546     3504963  2008      6          30          1     1337        1300
# 1048547     3504994  2008      6           1          7     1340        1245
# 1048548     3504995  2008      6           2          1     1330        1245
# 1048549     3504998  2008      6           5          4     1357        1245
# 1048550     3505003  2008      6          10          2     1254        1245
# 1048551     3505004  2008      6          11          3     1304        1245
# 1048552     3505006  2008      6          13          5     1255        1245
# 1048553     3505010  2008      6          17          2     1424        1245
# 1048554     3505011  2008      6          18          3     1255        1245
# 1048555     3505012  2008      6          19          4     1259        1245
# 1048556     3505014  2008      6          21          6     1301        1245
# 1048557     3505015  2008      6          22          7     1305        1245
# 1048558     3505018  2008      6          25          3     1259        1245
# 1048559     3505021  2008      6          28          6     1308        1245
# 1048560     3505022  2008      6          29          7     1308        1245
# 1048561     3505024  2008      6           1          7     1559        1535
# 1048562     3505027  2008      6           4          3     1617        1535
# 1048563     3505030  2008      6           7          6     1543        1535
# 1048564     3505031  2008      6           8          7     1623        1535
# 1048565     3505033  2008      6          10          2     1623        1535
# 1048566     3505035  2008      6          12          4     1545        1535
# 1048567     3505036  2008      6          13          5     1609        1535
# 1048568     3505037  2008      6          14          6     1616        1535
# 1048569     3505040  2008      6          17          2     1617        1535
# 1048570     3505042  2008      6          19          4     1551        1535
# 1048571     3505043  2008      6          20          5     1555        1535
# 1048572     3505044  2008      6          21          6     1555        1535
# 1048573     3505045  2008      6          22          7     1607        1535
# 1048574     3505046  2008      6          23          1     1608        1535
#
#          ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0         2211.0        2225            WN  ...     4.0       8          0
# 1         1002.0        1000            WN  ...     5.0      10          0
# 2          804.0         750            WN  ...     3.0      17          0
# 3         1959.0        1925            WN  ...     3.0      10          0
# 4         2121.0        2110            WN  ...     4.0      10          0
# 5         2037.0        1940            WN  ...     3.0       7          0
# 6          916.0         915            WN  ...     5.0      19          0
# 7         1845.0        1725            WN  ...     6.0       8          0
# 8         1021.0        1010            WN  ...     6.0       9          0
# 9         1640.0        1625            WN  ...     7.0       8          0
# 10         940.0         955            WN  ...     5.0      16          0
# 11        1526.0        1510            WN  ...     4.0       9          0
# 12        1512.0        1435            WN  ...     2.0       5          0
# 13        1754.0        1735            WN  ...     5.0       5          0
# 14        1956.0        1950            WN  ...     2.0       5          0
# 15        1133.0        1140            WN  ...     2.0       5          0
# 16        1619.0        1605            WN  ...     2.0       7          0
# 17        1657.0        1610            WN  ...     6.0       6          0
# 18        2239.0        2235            WN  ...     3.0       7          0
# 19        2334.0        2230            WN  ...     6.0       7          0
# 20        1546.0        1550            WN  ...     7.0       7          0
# 21        1715.0        1720            WN  ...     6.0       6          0
# 22        1859.0        1845            WN  ...     5.0       6          0
# 23        1927.0        1815            WN  ...     6.0      11          0
# 24        1235.0        1230            WN  ...     9.0       5          0
# 25        1531.0        1520            WN  ...     8.0       6          0
# 26        1559.0        1530            WN  ...     5.0       5          0
# 27        2019.0        2030            WN  ...     4.0       8          0
# 28         958.0        1020            WN  ...     4.0       8          0
# 29         929.0         955            WN  ...     3.0       9          0
# ...          ...         ...           ...  ...     ...     ...        ...
# 1048545   1552.0        1555            AA  ...     4.0      14          0
# 1048546   1624.0        1555            AA  ...     5.0       9          0
# 1048547   1720.0        1640            AA  ...     4.0      21          0
# 1048548   1729.0        1640            AA  ...     8.0      12          0
# 1048549   1753.0        1640            AA  ...     4.0      18          0
# 1048550   1635.0        1640            AA  ...     4.0      12          0
# 1048551   1654.0        1640            AA  ...     5.0      16          0
# 1048552   1639.0        1640            AA  ...     4.0      14          0
# 1048553   1854.0        1640            AA  ...     5.0      47          0
# 1048554   1657.0        1640            AA  ...     9.0      15          0
# 1048555   1644.0        1640            AA  ...     6.0      13          0
# 1048556   1649.0        1640            AA  ...     7.0      19          0
# 1048557   1712.0        1640            AA  ...     5.0      12          0
# 1048558   1705.0        1640            AA  ...     5.0      13          0
# 1048559   1657.0        1640            AA  ...     7.0      14          0
# 1048560   1715.0        1640            AA  ...     6.0      26          0
# 1048561   1921.0        1915            AA  ...     7.0      13          0
# 1048562   1945.0        1915            AA  ...     4.0      15          0
# 1048563   1912.0        1915            AA  ...     6.0      10          0
# 1048564   1957.0        1915            AA  ...     8.0      16          0
# 1048565   2003.0        1915            AA  ...     8.0      16          0
# 1048566   1944.0        1915            AA  ...     7.0      24          0
# 1048567   1942.0        1915            AA  ...     7.0      15          0
# 1048568   1954.0        1915            AA  ...    11.0      11          0
# 1048569   2002.0        1915            AA  ...     7.0      17          0
# 1048570   1923.0        1915            AA  ...     5.0      20          0
# 1048571   1927.0        1915            AA  ...     6.0      14          0
# 1048572   1917.0        1915            AA  ...     5.0      13          0
# 1048573   1941.0        1915            AA  ...     5.0      12          0
# 1048574   1933.0        1915            AA  ...     6.0      10          0
#
#          CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 0                       N         0           NaN           NaN      NaN
# 1                       N         0           NaN           NaN      NaN
# 2                       N         0           NaN           NaN      NaN
# 3                       N         0           2.0           0.0      0.0
# 4                       N         0           NaN           NaN      NaN
# 5                       N         0          10.0           0.0      0.0
# 6                       N         0           NaN           NaN      NaN
# 7                       N         0           8.0           0.0      0.0
# 8                       N         0           NaN           NaN      NaN
# 9                       N         0           3.0           0.0      0.0
# 10                      N         0           NaN           NaN      NaN
# 11                      N         0           0.0           0.0      0.0
# 12                      N         0          12.0           0.0      0.0
# 13                      N         0           7.0           0.0      0.0
# 14                      N         0           NaN           NaN      NaN
# 15                      N         0           NaN           NaN      NaN
# 16                      N         0           NaN           NaN      NaN
# 17                      N         0          40.0           0.0      0.0
# 18                      N         0           NaN           NaN      NaN
# 19                      N         0           5.0           0.0      0.0
# 20                      N         0           NaN           NaN      NaN
# 21                      N         0           NaN           NaN      NaN
# 22                      N         0           NaN           NaN      NaN
# 23                      N         0           3.0           0.0      0.0
# 24                      N         0           NaN           NaN      NaN
# 25                      N         0           NaN           NaN      NaN
# 26                      N         0           0.0           0.0      0.0
# 27                      N         0           NaN           NaN      NaN
# 28                      N         0           NaN           NaN      NaN
# 29                      N         0           NaN           NaN      NaN
# ...                   ...       ...           ...           ...      ...
# 1048545                 N         0           NaN           NaN      NaN
# 1048546                 N         0           0.0           3.0      0.0
# 1048547                 N         0          28.0           0.0      0.0
# 1048548                 N         0           2.0           0.0      4.0
# 1048549                 N         0          72.0           0.0      1.0
# 1048550                 N         0           NaN           NaN      NaN
# 1048551                 N         0           NaN           NaN      NaN
# 1048552                 N         0           NaN           NaN      NaN
# 1048553                 N         0           0.0          79.0     35.0
# 1048554                 N         0           5.0           0.0      7.0
# 1048555                 N         0           NaN           NaN      NaN
# 1048556                 N         0           NaN           NaN      NaN
# 1048557                 N         0           4.0           0.0     12.0
# 1048558                 N         0           2.0           0.0     11.0
# 1048559                 N         0           9.0           0.0      0.0
# 1048560                 N         0          14.0           0.0     12.0
# 1048561                 N         0           NaN           NaN      NaN
# 1048562                 N         0           0.0           0.0      0.0
# 1048563                 N         0           NaN           NaN      NaN
# 1048564                 N         0          42.0           0.0      0.0
# 1048565                 N         0          46.0           0.0      0.0
# 1048566                 N         0          10.0           0.0     19.0
# 1048567                 N         0          27.0           0.0      0.0
# 1048568                 N         0          11.0           0.0      0.0
# 1048569                 N         0           0.0          22.0      5.0
# 1048570                 N         0           NaN           NaN      NaN
# 1048571                 N         0           NaN           NaN      NaN
# 1048572                 N         0           NaN           NaN      NaN
# 1048573                 N         0           1.0           0.0      0.0
# 1048574                 N         0          18.0           0.0      0.0
#
#         SecurityDelay  LateAircraftDelay
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN                NaN
# 3                 0.0               32.0
# 4                 NaN                NaN
# 5                 0.0               47.0
# 6                 NaN                NaN
# 7                 0.0               72.0
# 8                 NaN                NaN
# 9                 0.0               12.0
# 10                NaN                NaN
# 11                0.0               16.0
# 12                0.0               25.0
# 13                0.0               12.0
# 14                NaN                NaN
# 15                NaN                NaN
# 16                NaN                NaN
# 17                0.0                7.0
# 18                NaN                NaN
# 19                0.0               59.0
# 20                NaN                NaN
# 21                NaN                NaN
# 22                NaN                NaN
# 23                0.0               69.0
# 24                NaN                NaN
# 25                NaN                NaN
# 26                0.0               29.0
# 27                NaN                NaN
# 28                NaN                NaN
# 29                NaN                NaN
# ...               ...                ...
# 1048545           NaN                NaN
# 1048546           0.0               26.0
# 1048547           0.0               12.0
# 1048548           0.0               43.0
# 1048549           0.0                0.0
# 1048550           NaN                NaN
# 1048551           NaN                NaN
# 1048552           NaN                NaN
# 1048553           0.0               20.0
# 1048554           0.0                5.0
# 1048555           NaN                NaN
# 1048556           NaN                NaN
# 1048557           0.0               16.0
# 1048558           0.0               12.0
# 1048559           0.0                8.0
# 1048560           0.0                9.0
# 1048561           NaN                NaN
# 1048562           0.0               30.0
# 1048563           NaN                NaN
# 1048564           0.0                0.0
# 1048565           0.0                2.0
# 1048566           0.0                0.0
# 1048567           0.0                0.0
# 1048568           0.0               28.0
# 1048569           0.0               20.0
# 1048570           NaN                NaN
# 1048571           NaN                NaN
# 1048572           NaN                NaN
# 1048573           0.0               25.0
# 1048574           0.0                0.0
#
# [1048575 rows x 30 columns]

# %% [markdown]
# Data Munging or Data cleaning

# %%
air.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Unnamed: 0                0
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                3896
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# TailNum                   4
# ActualElapsedTime      3896
# CRSElapsedTime          157
# AirTime                3896
# ArrDelay               3896
# DepDelay                  0
# Origin                    0
# Dest                      0
# Distance                  0
# TaxiIn                 3896
# TaxiOut                   0
# Cancelled                 0
# CancellationCode          0
# Diverted                  0
# CarrierDelay         362841
# WeatherDelay         362841
# NASDelay             362841
# SecurityDelay        362841
# LateAircraftDelay    362841
# dtype: int64

# %%
air['ArrTime'].mean()
# Out:
# 1610.7425285661911

# %%
air['ArrTime'].fillna('1610.742',inplace=True)

# %%
air['TailNum'].mode()
# Out:
# 0    N325SW
# dtype: object

# %%
air['TailNum'].fillna('N325SW',inplace=True)

# %%
air['ActualElapsedTime'].mean()
# Out:
# 131.6941902728015

# %%
air['ActualElapsedTime'].fillna('131.694',inplace=True)

# %%
air['CRSElapsedTime'].mean()
# Out:
# 132.30098109723411

# %%
air['CRSElapsedTime'].fillna(132.3,inplace=True)

# %%
air['AirTime'].mean()
# Out:
# 107.02498375098953

# %%
air['ArrDelay'].mean()
# Out:
# 42.18256804243217

# %%
air['AirTime'].fillna(107.024,inplace=True)

# %%
air['ArrDelay'].fillna(42.182,inplace=True)

# %%
air['TaxiIn'].mean()
# Out:
# 6.683526710118611

# %%
air['TaxiIn'].fillna(6.683,inplace=True)

# %%
air['CarrierDelay'].mean()
# Out:
# 18.870359352168624

# %%
air['WeatherDelay'].mean()
# Out:
# 3.5680322107406077

# %%
air['CarrierDelay'].fillna(18.87,inplace=True)

# %%
air['WeatherDelay'].fillna(3.568,inplace=True)

# %%
air['NASDelay'].mean()
# Out:
# 14.429618481801981

# %%
air['NASDelay'].fillna(14.429,inplace=True)

# %%
air['SecurityDelay'].mean()
# Out:
# 0.09328398475210505

# %%
air['LateAircraftDelay'].mean()
# Out:
# 25.334310388576327

# %%
air['LateAircraftDelay'].fillna(25.334,inplace=True)

# %%
air['SecurityDelay'].fillna(0.093,inplace=True)

# %%
air.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Unnamed: 0           0
# Year                 0
# Month                0
# DayofMonth           0
# DayOfWeek            0
# DepTime              0
# CRSDepTime           0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# FlightNum            0
# TailNum              0
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DepDelay             0
# Origin               0
# Dest                 0
# Distance             0
# TaxiIn               0
# TaxiOut              0
# Cancelled            0
# CancellationCode     0
# Diverted             0
# CarrierDelay         0
# WeatherDelay         0
# NASDelay             0
# SecurityDelay        0
# LateAircraftDelay    0
# dtype: int64

# %% [markdown]
# Regression analysis

# %%
output=air['ArrDelay']

# %%
input1=air['ArrTime']

# %%
air['ArrDelay'].hist(bins=100)

# %%
air.boxplot(column='ArrDelay')

# %%
plt.plot(input1,output,'o')

# %%
air[['ArrDelay','DepDelay','Distance','CarrierDelay','WeatherDelay','SecurityDelay','LateAircraftDelay']].corr()
# Out:
#                    ArrDelay  DepDelay  Distance  CarrierDelay  WeatherDelay  \
# ArrDelay           1.000000  0.948998 -0.032942      0.441576      0.221467
# DepDelay           0.948998  1.000000 -0.010354      0.484613      0.211607
# Distance          -0.032942 -0.010354  1.000000      0.017598     -0.024694
# CarrierDelay       0.441576  0.484613  0.017598      1.000000     -0.068260
# WeatherDelay       0.221467  0.211607 -0.024694     -0.068260      1.000000
# SecurityDelay     -0.003554 -0.003614  0.003807     -0.019489     -0.007867
# LateAircraftDelay  0.406530  0.456103 -0.006190     -0.184778     -0.060096
#
#                    SecurityDelay  LateAircraftDelay
# ArrDelay               -0.003554           0.406530
# DepDelay               -0.003614           0.456103
# Distance                0.003807          -0.006190
# CarrierDelay           -0.019489          -0.184778
# WeatherDelay           -0.007867          -0.060096
# SecurityDelay           1.000000          -0.020399
# LateAircraftDelay      -0.020399           1.000000

# %%
#air['ArrTime'].value_counts()

# %%
import statsmodels.api as sm     
#model=sm.OLS('ArrTime','ArrDelay').fit()
#model

# %%
import seaborn as sns

# %%
air.dtypes
# Out:
# Unnamed: 0             int64
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime                int64
# CRSDepTime             int64
# ArrTime               object
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime     object
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay               int64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut                int64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
air[['ArrTime','ArrDelay','DepDelay','CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay']].corr()
# Out:
#                    ArrDelay  DepDelay  CarrierDelay  WeatherDelay  NASDelay  \
# ArrDelay           1.000000  0.948998      0.441576      0.221467  0.330690
# DepDelay           0.948998  1.000000      0.484613      0.211607  0.210543
# CarrierDelay       0.441576  0.484613      1.000000     -0.068260 -0.116690
# WeatherDelay       0.221467  0.211607     -0.068260      1.000000 -0.000995
# NASDelay           0.330690  0.210543     -0.116690     -0.000995  1.000000
# SecurityDelay     -0.003554 -0.003614     -0.019489     -0.007867 -0.012207
# LateAircraftDelay  0.406530  0.456103     -0.184778     -0.060096 -0.119492
#
#                    SecurityDelay  LateAircraftDelay
# ArrDelay               -0.003554           0.406530
# DepDelay               -0.003614           0.456103
# CarrierDelay           -0.019489          -0.184778
# WeatherDelay           -0.007867          -0.060096
# NASDelay               -0.012207          -0.119492
# SecurityDelay           1.000000          -0.020399
# LateAircraftDelay      -0.020399           1.000000

# %%
plt.plot(air['ArrDelay'],air['DepDelay'])

# %%
y=air['ArrDelay']
X=air['DepDelay']

# %%
from sklearn.model_selection import train_test_split

# %%
X=X.values.reshape(-1,1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
X
# Out:
# array([[ 8],
#        [19],
#        [ 8],
#        ...,
#        [20],
#        [32],
#        [33]], dtype=int64)

# %%
X_train
# Out:
# array([[24],
#        [34],
#        [17],
#        ...,
#        [25],
#        [78],
#        [19]], dtype=int64)

# %%
from sklearn import linear_model as lm

# %%
model=lm.LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
accuracy=model.score(X_train,y_train)
accuracy
# Out:
# 0.9003903482069168

# %%
predictions=model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.9009055955446214

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,predictions)

# %%
print('intercept:',model.intercept_)
print('slope:',model.coef_)
# Out:
# intercept: -0.8817281438820288
# slope: [1.00694381]

# %%
y=5.044+10*0.89
y
# Out:
# 13.943999999999999

# %% [markdown]
# MULTILINEAR REGRESSION ,PREDICTOR=DepDelay,CarrierDelay TARGETOR=ArrDelay

# %%
a=air[['DepDelay','CarrierDelay']]
b=air['ArrDelay']
c=air[['DepDelay','SecurityDelay']]

# %%
import statsmodels.api as sm

# %%
model_=sm.OLS(b,a).fit()

# %%
model_.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ArrDelay   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                 7.807e+06
# Date:                Thu, 06 Jun 2019   Prob (F-statistic):               0.00
# Time:                        11:31:14   Log-Likelihood:            -4.4904e+06
# No. Observations:             1048575   AIC:                         8.981e+06
# Df Residuals:                 1048573   BIC:                         8.981e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# DepDelay         1.0134      0.000   3112.474      0.000       1.013       1.014
# CarrierDelay    -0.0404      0.001    -72.798      0.000      -0.041      -0.039
# ==============================================================================
# Omnibus:                   466628.933   Durbin-Watson:                   1.737
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        158622250.650
# Skew:                           0.886   Prob(JB):                         0.00
# Kurtosis:                      63.228   Cond. No.                         2.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_=sm.OLS(b,c).fit()
model_.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ArrDelay   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                 7.765e+06
# Date:                Thu, 06 Jun 2019   Prob (F-statistic):               0.00
# Time:                        11:31:15   Log-Likelihood:            -4.4931e+06
# No. Observations:             1048575   AIC:                         8.986e+06
# Df Residuals:                 1048573   BIC:                         8.986e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# DepDelay          0.9985      0.000   3938.646      0.000       0.998       0.999
# SecurityDelay    -0.0247      0.011     -2.327      0.020      -0.045      -0.004
# ==============================================================================
# Omnibus:                   480492.797   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        143523459.870
# Skew:                           0.986   Prob(JB):                         0.00
# Kurtosis:                      60.281   Cond. No.                         41.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn import linear_model as lm
from sklearn.model_selection import train_test_split

# %%
model3=lm.LinearRegression()

# %%
a_train,a_test,b_train,b_test = train_test_split(a,b,test_size=0.4,random_state=1)

# %%
model3.fit(a_train,b_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
accuracy1=model3.score(a_train,b_train)
accuracy1
# Out:
# 0.9008193352842784

# %%
predictions=model3.predict(a_train)

# %%
predictions_=model3.predict(a_test)

# %%
accuracy2=model3.score(a_test,b_test)
accuracy2
# Out:
# 0.9013586078795759

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
rmse_train=np.sqrt(mean_squared_error(b_train,predictions))
rmse_train
# Out:
# 17.519254894053418

# %%
r2_train=r2_score(b_train,predictions)
r2_train
# Out:
# 0.9008193352842784

# %%
rmse_test=np.sqrt(mean_squared_error(b_test,predictions_))
rmse_test
# Out:
# 17.50450103994227

# %%
r2_test=r2_score(b_test,predictions_)
r2_test
# Out:
# 0.9013586078795759

# %%
xnew=[[12,15]]

# %%
model3.predict(xnew)
# Out:
# array([10.97396311])
