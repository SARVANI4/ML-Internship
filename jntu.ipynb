# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.chdir("C:/Users/saisaran/Desktop/DATA_SETS")

# %%
data=pd.read_excel("jntu.xlsx")

# %%
data.head()
# Out:
#        State Division        Region        Branch Route Code     Village Name  \
# 0  Karnataka    KA 02  GOWRIBIDANUR  Gowribidanur   KGAWGAWD  Ramachandrapura
# 1  Karnataka    KA 02   VIJAYAPURAM   Vijaypura-2   KVIJVIBC   sadapana halli
# 2  Karnataka    KA 01   VIJAYAPURAM   Vijaypura-2   KVIJVIBC        yanagante
# 3  Karnataka    KA 02   VIJAYAPURAM   Vijaypura-2   KVIJVIBC        yanagante
# 4  Karnataka    KA 02   VIJAYAPURAM   Vijaypura-2   KVIJVIBC       sathyavara
#
#    pincode        Center Name  Group Name                  Name  Loan nature  \
# 0   504273    Ramachandrapura        Rama       Vadand Geetaben            1
# 1   504293  sadapanahalli new  sumithra 1   Co Patel Manjulaben            1
# 2   504307          yanagante  lakshmamma     Ghanchi Aminabibi            1
# 3   504001          yanagante     fincare  Ghanchi Farajanabanu            1
# 4   504001         sathyavara     saibaba  Ghanchee Shabanabanu            1
#
# ...

# %%
data.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# State                          0
# Division                       0
# Region                         0
# Branch                         1
# Route Code                     0
# Village Name                   0
# pincode                        0
# Center Name                    0
# Group Name                     0
# Name                           0
# Loan nature                    0
# Employee Name for clinet       0
# Existing Loan amount           0
# Loan Date                      0
# AGE                            0
# ID_DETAILS                     0
# ADHAAR NUMBER                  0
# Marital_Status                 0
# INCOME SOURCE               3435
# LoanStatus                  4941
# dtype: int64

# %%
data['Loan nature'].value_counts()
# Out:
# 1    13370
# 2       65
# Name: Loan nature, dtype: int64

# %%
data['Branch'].fillna('Doddaballapur',inplace=True)

# %%
data.dtypes
# Out:
# State                               object
# Division                            object
# Region                              object
# Branch                              object
# Route Code                          object
# Village Name                        object
# pincode                              int64
# Center Name                         object
# Group Name                          object
# Name                                object
# Loan nature                          int64
# Employee Name for clinet            object
# Existing Loan amount                 int64
# Loan Date                   datetime64[ns]
# AGE                                  int64
# ID_DETAILS                          object
# ADHAAR NUMBER                        int64
# Marital_Status                      object
# INCOME SOURCE                       object
# LoanStatus                          object
# dtype: object

# %%
data['INCOME SOURCE'].mode()
# Out:
# 0    BUSINESS
# dtype: object

# %%
data['INCOME SOURCE'].fillna('BUSINESS',inplace=True)

# %%
data['LoanStatus'].value_counts()
# Out:
# YES    5965
# NO     2529
# Name: LoanStatus, dtype: int64

# %%
data['LoanStatus'].fillna('YES',inplace=True)

# %%
data.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# State                       0
# Division                    0
# Region                      0
# Branch                      0
# Route Code                  0
# Village Name                0
# pincode                     0
# Center Name                 0
# Group Name                  0
# Name                        0
# Loan nature                 0
# Employee Name for clinet    0
# Existing Loan amount        0
# Loan Date                   0
# AGE                         0
# ID_DETAILS                  0
# ADHAAR NUMBER               0
# Marital_Status              0
# INCOME SOURCE               0
# LoanStatus                  0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
le=LabelEncoder()

# %%
data['LoanStatus']=le.fit_transform(data['LoanStatus'])
data['INCOME SOURCE']=le.fit_transform(data['INCOME SOURCE'])

# %%
data
# Out:
#             State Division         Region        Branch Route Code  \
# 0       Karnataka    KA 02   GOWRIBIDANUR  Gowribidanur   KGAWGAWD
# 1       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 2       Karnataka    KA 01    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 3       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 4       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 5       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 6       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 7       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 8       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 9       Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 10      Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 11      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 12      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# ...

# %%
data['Marital_Status']=le.fit_transform(data['Marital_Status'])

# %%
X=data.iloc[:,[12,14,17,18]]
y=data.iloc[:,[19]]

# %%
X
# Out:
#        Existing Loan amount   AGE  Marital_Status  INCOME SOURCE
# 0                     182050   31               1              1
# 1                      13325   33               1              0
# 2                     112780   38               1              0
# 3                      64290   43               1              2
# 4                      43947   40               1              5
# 5                      12025   19               1              5
# 6                      85392   28               1              0
# 7                     137631   41               1              2
# 8                     100147   45               1              0
# 9                      80731   23               1              0
# 10                     77204   41               2              1
# 11                     55029   28               1              5
# 12                    224832   36               1              2
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=0)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model.logistic import LogisticRegression
lgsr=LogisticRegression(random_state=0)
lgsr.fit(x_train,y_train)
# Out:
# C:\Users\saisaran\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\saisaran\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=lgsr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.810383327130629

# %%
new=[[1]]
lgsr.predict(new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-f47ff5c222bf> in <module>
#       1 new=[[1]]
# ----> 2 lgsr.predict(new)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     279             Predicted class label per sample.
#     280         """
# --> 281         scores = self.decision_function(X)
#     282         if len(scores.shape) == 1:
#     283             indices = (scores > 0).astype(np.int)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     260         if X.shape[1] != n_features:
#     261             raise ValueError("X has %d features per sample; expecting %d"
# --> 262                              % (X.shape[1], n_features))
#     263
#     264         scores = safe_sparse_dot(X, self.coef_.T,
#
# ...

# %%
from sklearn.metrics import confusion_matrix
conf_matrix=confusion_matrix(y_pred,y_test)
conf_matrix
# Out:
# array([[   0,    0],
#        [1019, 4355]], dtype=int64)

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
svm=SVC(kernel='rbf')

# %%
svm.fit(x_train,y_train)
# Out:
# C:\Users\saisaran\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\saisaran\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
svm.score(x_test,y_test)
# Out:
# 0.8100111648678824

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
classifier=KNeighborsClassifier(n_neighbors=5)

# %%
classifier.fit(x_train,y_train)
# Out:
# C:\Users\saisaran\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred=classifier.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
classifier.score(x_test,y_test)
# Out:
# 0.7841458876069967
